# %% [markdown]
# # **Tokenization**

# %%
#Tokenization
# !pip install --upgrade transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 41.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.13.1
#     Uninstalling transformers-5.13.1:
#       Successfully uninstalled transformers-5.13.1
# ...

# %% [markdown]
# # **Create the tokenization model**

# %% [markdown]
# hugging face token add :- setting  > access token > set permission > "Enable access to public gated repositories"

# %%
import os
os.environ['HF_TOKEN'] = 'HF_TOKEN'

# %%
from huggingface_hub import notebook_login

# This will prompt you to enter your Hugging Face token
# Make sure you have accepted the model's terms on its Hugging Face page first.
notebook_login()

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained('google/gemma-7b')
tokenizer("h e y h")

# %% [markdown]
# # **Embeding**

# %%
# !pip install google-genai

# %%
from google import genai

client = genai.Client(api_key="AIza.............")

response = client.models.embed_content(
    model="gemini-embedding-001",
    contents="Aastha Valand this side."
)

print(response.embeddings)
print(len(response.embeddings[0].values))

# %% [markdown]
# # **Tokens**

# %%
input_tokens = tokenizer(
    "write the code for adding two numbers",
    return_tensors="pt"
)

print(input_tokens)

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

model_name = "google/gemma-7b"

tokenizer = AutoTokenizer.from_pretrained(model_name)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.bfloat16,
    device_map="auto"
)

# %%
out = model(input_ids = input_tokens["input_ids"])
out

# %% [markdown]
# # **Generation**

# %%
gen_out = model.generate(input_ids = input_tokens["input_ids"],max_new_tokens = 100)
gen_out

# %%
tokenizer.decode(gen_out)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3655/436819939.py in <cell line: 0>()
# ----> 1 tokenizer.decode(gen_out)
#
# NameError: name 'tokenizer' is not defined
